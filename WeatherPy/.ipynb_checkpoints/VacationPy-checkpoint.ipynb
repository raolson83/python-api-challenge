# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# Import API key
from api_keys_doc import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  port mathurin -19.6833   63.4167     24.47        81           9
# 1        1     nuku'alofa -21.1333 -175.2000     26.19        83          40
# 2        2    west island -12.1568   96.8225     24.99        88          75
# 3        3  blackmans bay -43.0167  147.3167     10.07        91          23
# 4        4       waitangi -43.9535 -176.5597     12.12        90         100
#
#    Wind Speed Country        Date
# 0        4.24      MU  1699214875
# 1        7.20      TO  1699214875
# 2        6.17      CC  1699214595
# 3        0.45      AU  1699214875
# 4        2.24      NZ  1699214875

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display


# Configure the map
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriImagery",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_city = city_data_df.loc[(city_data_df['Max Temp'] >=25) & (city_data_df['Max Temp'] <= 27) & (city_data_df['Humidity'] <= 40),:]

# Drop any rows with null values
ideal_city = ideal_city.dropna()



# Display sample data
ideal_city
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 25        25            ambon  -3.6954  128.1814     26.16        15
# 74        74     faya-largeau  17.9257   19.1043     26.88        16
# 242      242   mount pleasant  32.7941  -79.8626     26.08        31
# 285      285           bardai  11.6500    7.2333     26.80        31
# 310      310       burumburum  11.3911    8.7234     25.84        29
# 391      391           illizi  26.4833    8.4667     26.41        11
# 421      421           lupane -18.9315   27.8070     26.22        33
# 424      424  cerqueira cesar -23.0356  -49.1661     26.03        40
# 432      432         ad dilam  23.9915   47.1627     26.23        40
# 548      548     tres arroyos -38.3739  -60.2798     26.99        28
#
#      Cloudiness  Wind Speed Country        Date
# 25           20        3.09      ID  1699214879
# 74            0        5.50      TD  1699214886
# 242           0        2.06      US  1699214915
# 285          73        3.96      NG  1699214922
# 310           6        2.57      NG  1699214926
# 391           0        4.14      DZ  1699214939
# 421          55        2.08      ZW  1699214946
# 424           0        3.69      BR  1699214745
# 432           5        0.86      SA  1699214949
# 548          76        7.21      AR  1699214923

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity

hotel_df = ideal_city[['City', 'Country', 'Lat','Lng', 'Humidity']].copy(deep=True).reset_index()
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df['Hotel Name'] = ''
# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#    index             City Country      Lat       Lng  Humidity Hotel Name
# 0     25            ambon      ID  -3.6954  128.1814        15
# 1     74     faya-largeau      TD  17.9257   19.1043        16
# 2    242   mount pleasant      US  32.7941  -79.8626        31
# 3    285           bardai      NG  11.6500    7.2333        31
# 4    310       burumburum      NG  11.3911    8.7234        29
# 5    391           illizi      DZ  26.4833    8.4667        11
# 6    421           lupane      ZW -18.9315   27.8070        33
# 7    424  cerqueira cesar      BR -23.0356  -49.1661        40
# 8    432         ad dilam      SA  23.9915   47.1627        40
# 9    548     tres arroyos      AR -38.3739  -60.2798        28

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":10
}


# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row['Lat']
    longitude = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make an API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# https://api.geoapify.com/v2/places
# ambon - nearest hotel: Hotel Hero
# https://api.geoapify.com/v2/places
# faya-largeau - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places
# mount pleasant - nearest hotel: Old Village Post House
# https://api.geoapify.com/v2/places
# bardai - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places
# burumburum - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places
# illizi - nearest hotel: بوناقة
# https://api.geoapify.com/v2/places
# lupane - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places
# cerqueira cesar - nearest hotel: Spazio Verde
# https://api.geoapify.com/v2/places
# ad dilam - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places
# tres arroyos - nearest hotel: Andrea Hotel
#    index             City Country      Lat       Lng  Humidity  \
# 0     25            ambon      ID  -3.6954  128.1814        15
# 1     74     faya-largeau      TD  17.9257   19.1043        16
# 2    242   mount pleasant      US  32.7941  -79.8626        31
# 3    285           bardai      NG  11.6500    7.2333        31
# 4    310       burumburum      NG  11.3911    8.7234        29
# 5    391           illizi      DZ  26.4833    8.4667        11
# 6    421           lupane      ZW -18.9315   27.8070        33
# 7    424  cerqueira cesar      BR -23.0356  -49.1661        40
# 8    432         ad dilam      SA  23.9915   47.1627        40
# 9    548     tres arroyos      AR -38.3739  -60.2798        28
#
#                Hotel Name
# 0              Hotel Hero
# 1          No hotel found
# 2  Old Village Post House
# 3          No hotel found
# 4          No hotel found
# 5                  بوناقة
# 6          No hotel found
# 7            Spazio Verde
# 8          No hotel found
# 9            Andrea Hotel

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# Configure the map
map_plot_1 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriImagery",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 2,
    color = "City"
)

# Display the map plot
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)
